# %%
# %run get_image.py
# Out:
# Image Resolution:  (3000, 4000, 3)

# %%
# %run get_pixels.py

# %%
# %run convert_color.py

# %%
# %run drawings.py

# %%
# %run gamma_correction.py

# %%
# %run similarity.py
# Out:
# SSIM factor:  0.0011253760694860955
